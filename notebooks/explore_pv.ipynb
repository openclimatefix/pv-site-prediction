# %%
import pandas as pd
import xarray as xr
import os
import plotly.express as px

# %%
PV_DATA_PATH = '/mnt/leonardo/storage_b/data/ocf/solar_pv_nowcasting/clients/dual_ax/PV/dual_ax_tracker_15min_start.nc'
PV_DATA_PATH = "/mnt/leonardo/storage_b/data/ocf/solar_pv_nowcasting/clients/uk_pv/5min_v3.nc"
PV_DATA_PATH = "/mnt/leonardo/storage_b/data/ocf/solar_pv_nowcasting/clients/dual_ax/PV/dual_ax_tracker_in_diffuse_15min_mid_kw.nc"


ds = xr.open_dataset(PV_DATA_PATH)
df = ds.to_dataframe()
df = df.reset_index()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (pv_id: 1, ts: 3236)
# Coordinates:
#   * pv_id        (pv_id) int64 0
#     latitude     (pv_id) float64 ...
#     longitude    (pv_id) float64 ...
#     orientation  (pv_id) float64 ...
#     tilt         (pv_id) float64 ...
#     capacity     (pv_id) float64 ...
#   * ts           (ts) datetime64[ns] 2023-11-17T07:22:30 ... 2023-12-21T00:07:30
# Data variables:
#     power        (ts, pv_id) float64 ...

# %%
fig = px.line(df, x='ts', y='power')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fig = px.line(df, x='ts', y='power')
#       2 fig.show()
#
# NameError: name 'df' is not defined
